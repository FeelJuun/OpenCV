# %%
from google.colab import drive
drive.mount('/content/drive')
import cv2
from google.colab.patches import cv2_imshow
import numpy as np
import matplotlib.pyplot as plt
# Out:
# Mounted at /content/drive

# %%
img = cv2.imread('/content/drive/MyDrive/ColabIP/images/lena256.jpg')
RGB_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

gimg1 = cv2.cvtColor(RGB_img, cv2.COLOR_RGB2GRAY)
print(gimg1.shape)
cv2_imshow(gimg1)
# Out:
# (256, 256)
# <PIL.Image.Image image mode=L size=256x256>

# %%
hist = cv2.calcHist([gimg1], [0], None, [256], [0, 255])
plt.plot(hist)

# %%
#img = cv2.imread('/content/drive/MyDrive/ColabIP/images/rice.bmp')
#img = cv2.imread('/content/drive/MyDrive/ColabIP/images/cell.bmp')
img = cv2.imread('/content/drive/MyDrive/ColabIP/images/cell-bright.bmp')
RGB_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

gimg1 = cv2.cvtColor(RGB_img, cv2.COLOR_RGB2GRAY)
print(gimg1.shape)
cv2_imshow(gimg1)
# Out:
# (360, 360)
# <PIL.Image.Image image mode=L size=360x360>

# %%
hist = cv2.calcHist([gimg1], [0], None, [256], [0, 255])
plt.plot(hist)

# %%
gBin = np.zeros((gimg1.shape[0], gimg1.shape[1]))

# %%
T = 180

for h in range(gimg1.shape[0]):
  for w in range(gimg1.shape[1]):
    if gimg1[h,w] > T:
      gBin[h,w] = 255
    else:
      gBin[h,w] = 0

#plt.imshow(gBin, cmap = 'gray')
cv2_imshow(gBin)
# Out:
# <PIL.Image.Image image mode=L size=360x360>

# %%
T1 = 50
T2 = 0
T0 = 1
outimg = np.zeros((gimg1.shape[0], gimg1.shape[1]))

# %%
def threshold_update(h, w, gimg1, output, T1):
  sum1=0
  count1=1
  sum2=0
  count2=1

  for h in range(gimg1.shape[0]):
    for w in range(gimg1.shape[1]):
      if(output[h,w] == 255):
        sum1 = sum1 + gimg1[h,w]
        count1 = count1+1
      else:
        sum2 = sum2 + gimg1[h,w]
        count2 = count2+1

ave1 = sum1/count1
ave2 = sum2 / count2

T2 = np.int32(ave1 + ave2)/2
return T2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-34-342ad9f4095b> in <cell line: 16>()
#      14         count2 = count2+1
#      15
# ---> 16 ave1 = sum1/count1
#      17 ave2 = sum2 / count2
#      18
#
# NameError: name 'sum1' is not defined
